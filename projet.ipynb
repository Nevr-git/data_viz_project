# %% [markdown]
# # <center>Projet Data Visualisation</center>
# <center>Data pre-processing</center>

# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import seaborn as sb

# %%
data = pd.read_csv("data/prix-des-carburants-en-france-flux-instantane-v2.csv", sep=";")

# %%
data
# Out:
#             id   latitude  longitude  Code postal pop  \
# 0     56700006  4773600.0  -323200.0        56700   R
# 1     34170001  4362300.0   389800.0        34170   R
# 2     21300001  4728500.0   502200.0        21300   R
# 3     45300003  4818391.0   225072.0        45300   R
# 4     34990001  4361400.0   380900.0        34990   R
# ...        ...        ...        ...          ...  ..
# 9985  44000005  4723769.0  -153264.0        44300   R
# 9986  40500001  4374900.0   -56400.0        40500   R
# 9987  88200001  4800400.0   661300.0        88200   R
# 9988  56700009  4780400.0  -327000.0        56700   R
# 9989  84700005  4402700.0   487400.0        84700   R
#
#                               Adresse             Ville  \
# 0               5 Rue de la Madeleine        Merlevenez
# 1          753 Route de la Pompignane  Castelnau-le-Lez
# 2                   ZONE INDUSTRIELLE           Chenôve
# 3               Avenue du 11 Novembre        Pithiviers
# 4     Route de Saint Georges d'Orques          Juvignac
# ...                               ...               ...
# 9985         55 Boulevard Jules Verne            Nantes
# 9986          15 bis avenue du Tursan       Saint-Sever
# 9987              26 ROUTE DE BUSSANG        Remiremont
# 9988       32 AVENUE DE LA LIBERATION         Hennebont
# 9989                2232 AV. D'ORANGE           Sorgues
#
#                                                horaires  \
# 0                                                   NaN
# 1     {"@automate-24-24": "1", "jour": [{"@id": "1",...
# 2     {"@automate-24-24": "1", "jour": [{"@id": "1",...
# 3                                                   NaN
# 4     {"@automate-24-24": "1", "jour": [{"@id": "1",...
# ...                                                 ...
# 9985                                                NaN
# 9986  {"@automate-24-24": "", "jour": [{"@id": "1", ...
# 9987  {"@automate-24-24": "1", "jour": [{"@id": "1",...
# 9988  {"@automate-24-24": "", "jour": [{"@id": "1", ...
# 9989  {"@automate-24-24": "1", "jour": [{"@id": "1",...
#
#                                                services  \
# 0     {"service": ["Toilettes publiques", "Restaurat...
# 1     {"service": ["Boutique alimentaire", "Station ...
# 2     {"service": ["Station de gonflage", "Carburant...
# 3     {"service": ["Toilettes publiques", "Vente de ...
# 4     {"service": ["Location de véhicule", "Piste po...
# ...                                                 ...
# 9985                                                NaN
# 9986  {"service": ["Toilettes publiques", "Relais co...
# 9987  {"service": ["Toilettes publiques", "Laverie",...
# 9988                {"service": "Boutique alimentaire"}
# 9989  {"service": ["Toilettes publiques", "Boutique ...
#
#                                                    prix  ...  \
# 0     [{"@nom": "Gazole", "@id": "1", "@maj": "2023-...  ...
# 1     [{"@nom": "Gazole", "@id": "1", "@maj": "2023-...  ...
# 2     [{"@nom": "Gazole", "@id": "1", "@maj": "2023-...  ...
# 3     [{"@nom": "Gazole", "@id": "1", "@maj": "2023-...  ...
# 4     [{"@nom": "Gazole", "@id": "1", "@maj": "2023-...  ...
# ...                                                 ...  ...
# 9985  [{"@nom": "Gazole", "@id": "1", "@maj": "2023-...  ...
# 9986  [{"@nom": "Gazole", "@id": "1", "@maj": "2023-...  ...
# 9987  [{"@nom": "Gazole", "@id": "1", "@maj": "2023-...  ...
# 9988  [{"@nom": "Gazole", "@id": "1", "@maj": "2023-...  ...
# 9989  [{"@nom": "Gazole", "@id": "1", "@maj": "2023-...  ...
#
#                  SP98_maj SP98_prix     Carburants disponibles  \
# 0     2023-10-02 09:55:19     1.927        Gazole,E85,E10,SP98
# 1     2023-10-04 06:34:29     2.059        Gazole,E85,E10,SP98
# 2     2023-10-04 07:15:00     1.928       Gazole,GPLc,E10,SP98
# 3     2023-10-04 07:39:21     1.911  Gazole,SP95,GPLc,E10,SP98
# 4     2023-10-03 09:09:09     2.099   Gazole,E85,GPLc,E10,SP98
# ...                   ...       ...                        ...
# 9985  2023-09-06 16:43:00     1.990           Gazole,SP95,SP98
# 9986  2023-09-12 10:43:09     1.999           Gazole,SP95,SP98
# 9987  2023-10-03 09:27:39     1.999       Gazole,GPLc,E10,SP98
# 9988  2023-09-27 07:27:22     2.101            Gazole,E10,SP98
# 9989  2023-10-04 00:01:00     1.990            Gazole,E10,SP98
#
#      Carburants indisponibles  Automate 24-24 (oui/non)  \
# 0                   SP95,GPLc                       Non
# 1                   SP95,GPLc                       Oui
# 2                    SP95,E85                       Oui
# 3                         E85                       Non
# 4                        SP95                       Oui
# ...                       ...                       ...
# 9985             E85,GPLc,E10                       Non
# 9986             E85,GPLc,E10                       Non
# 9987                 SP95,E85                       Oui
# 9988            SP95,E85,GPLc                       Non
# 9989            SP95,E85,GPLc                       Oui
#
#                                                Services       Département  \
# 0     Toilettes publiques,Restauration à emporter,St...          Morbihan
# 1     Boutique alimentaire,Station de gonflage,Locat...           Hérault
# 2     Station de gonflage,Carburant additivé,Automat...         Côte-d'Or
# 3     Toilettes publiques,Vente de fioul domestique,...            Loiret
# 4     Location de véhicule,Piste poids lourds,Bornes...           Hérault
# ...                                                 ...               ...
# 9985                                                NaN  Loire-Atlantique
# 9986  Toilettes publiques,Relais colis,Location de v...            Landes
# 9987  Toilettes publiques,Laverie,Relais colis,Bouti...            Vosges
# 9988                               Boutique alimentaire          Morbihan
# 9989  Toilettes publiques,Boutique alimentaire,Stati...          Vaucluse
#
#      code_departement                      Région code_region
# 0                  56                    Bretagne        53.0
# 1                  34                   Occitanie        76.0
# 2                  21     Bourgogne-Franche-Comté        27.0
# 3                  45         Centre-Val de Loire        24.0
# 4                  34                   Occitanie        76.0
# ...               ...                         ...         ...
# 9985               44            Pays de la Loire        52.0
# 9986               40          Nouvelle-Aquitaine        75.0
# 9987               88                   Grand Est        44.0
# 9988               56                    Bretagne        53.0
# 9989               84  Provence-Alpes-Côte d'Azur        93.0
#
# [9990 rows x 31 columns]

# %%
data["id"]
# Out:
# 0       56700006
# 1       34170001
# 2       21300001
# 3       45300003
# 4       34990001
#           ...
# 9985    44000005
# 9986    40500001
# 9987    88200001
# 9988    56700009
# 9989    84700005
# Name: id, Length: 9990, dtype: int64
